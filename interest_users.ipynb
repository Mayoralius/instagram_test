# %%
import webbrowser

# %%
interest_users = [
    'lucianh_',
    'mercemartinez_',
    'esther.lucas26',
    'miguelcaballero88',
    'laura_sarria_landete',
    '_andreagracia_23',
    'marialp_2000',
    'antoniog19_',
    'jaimee_jimenez',
    'edugar_23',
    'carlosmoliniesta',
    'javiign_',
    'paulahsirvent',
    'deivid414h',
    'nataliacanotri',
    '__mchm',
    'letesgq20',
    'andrea_tebar',
    'javier_vano',
]

# %%
#chrome_path = '/usr/bin/google-chrome %s'
chrome_path = 'C:/Program Files (x86)/Google/Chrome/Application/chrome.exe %s'

# %%
for item in interest_users:
    url = 'https://www.instagram.com/%s/' %item
    webbrowser.get(chrome_path).open(url)
    print(url)
# Out:
# https://www.instagram.com/lucianh_/
# https://www.instagram.com/mercemartinez_/
# https://www.instagram.com/esther.lucas26/
# https://www.instagram.com/miguelcaballero88/
# https://www.instagram.com/laura_sarria_landete/
# https://www.instagram.com/_andreagracia_23/
# https://www.instagram.com/marialp_2000/
# https://www.instagram.com/antoniog19_/
# https://www.instagram.com/jaimee_jimenez/
# https://www.instagram.com/edugar_23/
# https://www.instagram.com/carlosmoliniesta/
# https://www.instagram.com/javiign_/
# https://www.instagram.com/paulahsirvent/
# https://www.instagram.com/deivid414h/
# https://www.instagram.com/nataliacanotri/
# https://www.instagram.com/__mchm/
# https://www.instagram.com/letesgq20/
# https://www.instagram.com/andrea_tebar/
# https://www.instagram.com/javier_vano/
